# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))

# Any results you write to the current directory are saved as output.
# Out:
# ['zillow_data_dictionary.xlsx', 'properties_2016.csv', 'sample_submission.csv', 'train_2017.csv', 'train_2016_v2.csv', 'properties_2017.csv']

# %%
dfs = pd.read_excel("../input/zillow_data_dictionary.xlsx", sheet_name=None)
dfs['Data Dictionary'].sort_values(by="Feature")
# Out:
#                            Feature                                        Description
# 0          'airconditioningtypeid'   Type of cooling system present in the home (i...
# 1       'architecturalstyletypeid'   Architectural style of the home (i.e. ranch, ...
# 55                'assessmentyear'           The year of the property tax assessment
# 2                   'basementsqft'   Finished living area below or partially below...
# 3                    'bathroomcnt'   Number of bathrooms in home including fractio...
# 4                     'bedroomcnt'                        Number of bedrooms in home
# 6            'buildingclasstypeid'  The building framing type (steel frame, wood f...
# 5          'buildingqualitytypeid'   Overall assessment of condition of the buildi...
# 7              'calculatedbathnbr'   Number of bathrooms in home including fractio...
# 11  'calculatedfinishedsquarefeet'   Calculated total finished living area of the ...
# 39           'censustractandblock'   Census tract and block ID combined - also con...
# 8                     'decktypeid'            Type of deck (if any) present on parcel
# 10      'finishedfloor1squarefeet'   Size of the finished living area on the first...
# 13          'finishedsquarefeet12'                               Finished living area
# 14          'finishedsquarefeet13'                             Perimeter  living area
# 15          'finishedsquarefeet15'                                         Total area
# 16          'finishedsquarefeet50'   Size of the finished living area on the first...
# 12           'finishedsquarefeet6'                  Base unfinished and finished area
# 17                          'fips'   Federal Information Processing Standard code ...
# 18                  'fireplacecnt'            Number of fireplaces in a home (if any)
# 19                 'fireplaceflag'               Is a fireplace present in this home
# 20                   'fullbathcnt'   Number of full bathrooms (sink, shower + bath...
# 21                  'garagecarcnt'   Total number of garages on the lot including ...
# 22               'garagetotalsqft'   Total number of square feet of all garages on...
# 23                'hashottuborspa'                Does the home have a hot tub or spa
# 24         'heatingorsystemtypeid'                        Type of home heating system
# 53         'landtaxvaluedollarcnt'  The assessed value of the land area of the parcel
# 25                      'latitude'   Latitude of the middle of the parcel multipli...
# 26                     'longitude'   Longitude of the middle of the parcel multipl...
# 27             'lotsizesquarefeet'                     Area of the lot in square feet
# 28               'numberofstories'           Number of stories or levels the home has
# 29                      'parcelid'              Unique identifier for parcels (lots)
# 30                       'poolcnt'                Number of pools on the lot (if any)
# 31                   'poolsizesum'      Total square footage of all pools on property
# 32                  'pooltypeid10'                                     Spa or Hot Tub
# 33                   'pooltypeid2'                              Pool with Spa/Hot Tub
# 34                   'pooltypeid7'                               Pool without hot tub
# 35     'propertycountylandusecode'   County land use code i.e. it's zoning at the ...
# 36         'propertylandusetypeid'         Type of land use the property is zoned for
# 37            'propertyzoningdesc'   Description of the allowed land uses (zoning)...
# 38        'rawcensustractandblock'   Census tract and block ID combined - also con...
# 41                  'regionidcity'     City in which the property is located (if any)
# 40                'regionidcounty'            County in which the property is located
# 43          'regionidneighborhood'      Neighborhood in which the property is located
# 42                   'regionidzip'          Zip code in which the property is located
# 44                       'roomcnt'   Total number of rooms in the principal residence
# 45                   'storytypeid'   Type of floors in a multi-story house (i.e. b...
# 52    'structuretaxvaluedollarcnt'  The assessed value of the built structure on t...
# 54                     'taxamount'  The total property tax assessed for that asses...
# 56            'taxdelinquencyflag'  Property taxes for this parcel are past due as...
# 57            'taxdelinquencyyear'  Year for which the unpaid propert taxes were due
# 51             'taxvaluedollarcnt'         The total tax assessed value of the parcel
# 9            'threequarterbathnbr'   Number of 3/4 bathrooms in house (shower + si...
# 46        'typeconstructiontypeid'   What type of construction material was used t...
# 47                       'unitcnt'   Number of units the structure is built into (...
# 48            'yardbuildingsqft17'                                     Patio in  yard
# 49            'yardbuildingsqft26'                      Storage shed/building in yard
# 50                     'yearbuilt'        The Year the principal residence was built

# %%
train17 = pd.read_csv("../input/train_2017.csv")
train17.head(5)
# Out:
#    parcelid  logerror transactiondate
# 0  14297519  0.025595      2017-01-01
# 1  17052889  0.055619      2017-01-01
# 2  14186244  0.005383      2017-01-01
# 3  12177905 -0.103410      2017-01-01
# 4  10887214  0.006940      2017-01-01

# %%
prop17=pd.read_csv("../input/properties_2017.csv")
prop17.head(5)
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (49) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    parcelid         ...           censustractandblock
# 0  10754147         ...                           NaN
# 1  10759547         ...                           NaN
# 2  10843547         ...                           NaN
# 3  10859147         ...                           NaN
# 4  10879947         ...                           NaN
#
# [5 rows x 58 columns]

# %%
df17 = pd.merge(train17, prop17, on=["parcelid"], how="left", indicator = True)

# %%
print("Dataset Size is %d "%(df17.shape[0]))
# Out:
# Dataset Size is 77613

# %%
np.round(np.array([17,19])/3,3)
# Out:
# array([5.667, 6.333])

# %%
def DisplayT(DF, target_feature):
    counts=DF.count()
    nulls=DF.apply(lambda col: col.isnull().sum())
    pct_nulls = np.round(nulls / DF.shape[0],5)
    uniques=DF.apply(lambda col: [col.unique()])
#    count_uniques = DF.apply(lambda col: len([col.unique()]))
    count_uniques=[len(lst) for lst in uniques.iloc[0,:].values]

    dtypes=DF.dtypes
    #tbl=pd.DataFrame(list(zip(uniques.iloc[0,:].values)), columns=["uniqueness"])
    
    tbl=pd.DataFrame(list(zip(DF.columns,counts, nulls,pct_nulls*100 ,dtypes, uniques.iloc[0,:].values,count_uniques,  DF.corr()[target_feature])), 
                     columns=["feature","non_empty_counts","nulls","pct_nulls","dtypes", "uniqueness", "count_unique","corr_betweem_target" ])
    tbl=tbl.set_index("feature")
    return(tbl)

# %% [markdown]
# ### This dataset contains 54 features with with 77613 instances.
# #### The following shows some information about the features
# - non_empty_counts: Number of Non-empty Cells of the specific feature
# - nulls: Number of Null cells of the specific feature
# - pct_nulls: Percent of null cells of the specific feature
# - dtype: Type of the feature
# - uniqueness: Sample of unique values of the specific feature
# - count_unique: Number of unique values of the specific feature
# - corr_betweem_target: Correlation value between the feature and Target Value

# %%
adf=DisplayT(df17, "logerror")
print(adf.shape)
display(adf.sort_values(by="nulls", ascending = False))
# Out:
# (54, 7)
#                               non_empty_counts         ...           corr_betweem_target
# feature                                                ...
# buildingclasstypeid                         15         ...                     -0.012987
# finishedsquarefeet13                        42         ...                     -0.041200
# storytypeid                                 50         ...                     -0.039753
# basementsqft                                50         ...                      0.025817
# yardbuildingsqft26                          70         ...                      0.003419
# fireplaceflag                              172         ...                      0.002199
# architecturalstyletypeid                   207         ...                      0.372067
# typeconstructiontypeid                     223         ...                      0.004861
# finishedsquarefeet6                        386         ...                      0.006413
# pooltypeid10                               465         ...                           NaN
# decktypeid                                 614         ...                     -0.012883
# poolsizesum                                869         ...                           NaN
# pooltypeid2                               1074         ...                     -0.005679
# hashottuborspa                            1539         ...                     -0.011726
# yardbuildingsqft17                        2393         ...                      0.008433
# finishedsquarefeet15                      3027         ...                     -0.018269
# finishedfloor1squarefeet                  6037         ...                      0.040516
# finishedsquarefeet50                      6037         ...                      0.072870
# fireplacecnt                              8289         ...                      0.027133
# threequarterbathnbr                      10106         ...                     -0.036867
# pooltypeid7                              15079         ...                      0.006333
# poolcnt                                  16174         ...                           NaN
# numberofstories                          17599         ...                      0.000501
# airconditioningtypeid                    25007         ...                     -0.011607
# garagecarcnt                             25520         ...                      0.035015
# garagetotalsqft                          25520         ...                     -0.006119
# regionidneighborhood                     30974         ...                      0.015540
# heatingorsystemtypeid                    49571         ...                      0.015876
# buildingqualitytypeid                    49809         ...                      0.029330
# propertyzoningdesc                       50476         ...                     -0.006319
# unitcnt                                  50703         ...                      0.008204
# lotsizesquarefeet                        69321         ...                      0.021174
# finishedsquarefeet12                     73923         ...                     -0.085549
# regionidcity                             76107         ...                      0.014567
# fullbathcnt                              76963         ...                      0.029002
# calculatedbathnbr                        76963         ...                           NaN
# yearbuilt                                77309         ...                           NaN
# calculatedfinishedsquarefeet             77378         ...                      0.045921
# structuretaxvaluedollarcnt               77464         ...                     -0.078575
# regionidzip                              77529         ...                     -0.000970
# taxvaluedollarcnt                        77578         ...                      0.004613
# roomcnt                                  77579         ...                      0.001999
# longitude                                77579         ...                           NaN
# regionidcounty                           77579         ...                           NaN
# rawcensustractandblock                   77579         ...                     -0.001295
# propertylandusetypeid                    77579         ...                     -0.016493
# propertycountylandusecode                77579         ...                      0.001070
# latitude                                 77579         ...                      0.011012
# fips                                     77579         ...                      0.023242
# bedroomcnt                               77579         ...                      0.315372
# bathroomcnt                              77579         ...                      0.031638
# logerror                                 77613         ...                      1.000000
# transactiondate                          77613         ...                      0.009341
# parcelid                                 77613         ...                      0.015407
#
# [54 rows x 7 columns]

# %% [markdown]
# ### Missing Values
# There are quite amount of missing values in some of the features, the following features with over 50% of missing are going to exclude from the dataset

# %%
display(adf[["pct_nulls", "dtypes"]][adf.pct_nulls>50].sort_values(by="pct_nulls", ascending = False))
# Out:
#                           pct_nulls   dtypes
# feature
# buildingclasstypeid          99.981  float64
# finishedsquarefeet13         99.946  float64
# basementsqft                 99.936  float64
# storytypeid                  99.936  float64
# yardbuildingsqft26           99.910  float64
# fireplaceflag                99.778   object
# architecturalstyletypeid     99.733  float64
# typeconstructiontypeid       99.713  float64
# finishedsquarefeet6          99.503  float64
# pooltypeid10                 99.401  float64
# decktypeid                   99.209  float64
# poolsizesum                  98.880  float64
# pooltypeid2                  98.616  float64
# hashottuborspa               98.017   object
# yardbuildingsqft17           96.917  float64
# finishedsquarefeet15         96.100  float64
# finishedsquarefeet50         92.222  float64
# finishedfloor1squarefeet     92.222  float64
# fireplacecnt                 89.320  float64
# threequarterbathnbr          86.979  float64
# pooltypeid7                  80.572  float64
# poolcnt                      79.161  float64
# numberofstories              77.325  float64
# airconditioningtypeid        67.780  float64
# garagetotalsqft              67.119  float64
# garagecarcnt                 67.119  float64
# regionidneighborhood         60.092  float64

# %% [markdown]
# ### The following features is going to be stayed for further analysis

# %%
display(adf[["pct_nulls", "dtypes"]][adf.pct_nulls<=50].sort_values(by="pct_nulls", ascending = False))
# Out:
#                               pct_nulls   dtypes
# feature
# heatingorsystemtypeid            36.131  float64
# buildingqualitytypeid            35.824  float64
# propertyzoningdesc               34.965   object
# unitcnt                          34.672  float64
# lotsizesquarefeet                10.684  float64
# finishedsquarefeet12              4.754  float64
# regionidcity                      1.940  float64
# calculatedbathnbr                 0.837  float64
# fullbathcnt                       0.837  float64
# yearbuilt                         0.392  float64
# calculatedfinishedsquarefeet      0.303  float64
# structuretaxvaluedollarcnt        0.192  float64
# regionidzip                       0.108  float64
# taxvaluedollarcnt                 0.045  float64
# regionidcounty                    0.044  float64
# roomcnt                           0.044  float64
# rawcensustractandblock            0.044  float64
# longitude                         0.044  float64
# propertylandusetypeid             0.044  float64
# propertycountylandusecode         0.044   object
# latitude                          0.044  float64
# fips                              0.044  float64
# bedroomcnt                        0.044  float64
# bathroomcnt                       0.044  float64
# logerror                          0.000  float64
# transactiondate                   0.000   object
# parcelid                          0.000    int64

# %% [markdown]
# ### Correlation

# %%
from collections import Counter
Counter(df17[df17["heatingorsystemtypeid"].isnull()==False]["heatingorsystemtypeid"])
# Out:
# Counter({2.0: 33633,
#          7.0: 14107,
#          6.0: 777,
#          24.0: 850,
#          13.0: 60,
#          18.0: 23,
#          20.0: 104,
#          1.0: 13,
#          10.0: 3,
#          11.0: 1})

# %%
sns.regplot(x=features[cnt], y="logerror", data=df17)
# Out:
# 'heatingorsystemtypeid'

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
fig = plt.figure(figsize=(15,100))


features=adf[["pct_nulls", "dtypes"]][adf.pct_nulls<=50].sort_values(by="pct_nulls", ascending = False).index
l = int(len(features)/2)
cnt=0
while cnt <=len(features):
    for row in range(l):
        for col in range(2):
            try:
                plt.subplot2grid((l,2),(row,col))
                sns.regplot(x=features[cnt], y="logerror", data=df17)
                cnt+1
            except:
                cnt+=1
                pass

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

features=adf[["pct_nulls", "dtypes"]][adf.pct_nulls<=50].sort_values(by="pct_nulls", ascending = False).index
w = len(features)/3

fig = plt.figure(figsize=(15,100))
for i in range(2):

    ax = fig.add_subplot(int("%d%d%d"%(int(w) , 3, i+1)))
    try:
        sns.regplot(x=features[i], y="logerror", data=df17, color="orange")
    except:
        pass
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-7657417926b6> in <module>()
#      10 for i in range(len(features)):
#      11
# ---> 12     ax = fig.add_subplot(int("%d%d%d"%(int(w) , 3, i+1)))
#      13     try:
#      14         sns.regplot(x=features[i], y="logerror", data=df17, color="orange")
#
# /opt/conda/lib/python3.6/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1333             if not 100 <= args[0] <= 999:
#    1334                 raise ValueError("Integer subplot specification must be a "
# -> 1335                                  "three-digit number, not {}".format(args[0]))
#    1336             args = tuple(map(int, str(args[0])))
#    1337
#
# ValueError: Integer subplot specification must be a three-digit number, not 9310

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

features=adf[["pct_nulls", "dtypes"]][adf.pct_nulls<=50].sort_values(by="pct_nulls", ascending = False).index

fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(2,2,1)
sns.regplot(x="heatingorsystemtypeid", y="logerror", data=df17, color="orange")

ax = fig.add_subplot(2,2,2)
sns.regplot(x="buildingqualitytypeid", y="logerror", data=df17, color="blue")

ax = fig.add_subplot(2,2,3)
sns.regplot(x="unitcnt", y="logerror", data=df17, color="red")


plt.show()
